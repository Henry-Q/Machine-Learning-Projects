# %% [markdown]
# # LAB 9A - TIME SERIES
#
# This lab is comprised of 4 parts:
#
# - 1. Linear Trend Models
#
# - 2. Random Walk Models
#
# - 3. Auto-regressive Models
#
# - 4. Random Forest Models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('sales.csv')
sales.info()
sales.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales          781 non-null    int64
#  1   Date           781 non-null    object
#  2   Promo          781 non-null    int64
#  3   SchoolHoliday  781 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 24.5+ KB
#    Sales        Date  Promo  SchoolHoliday
# 0   5530  2013-01-02      0              1
# 1   4327  2013-01-03      0              1
# 2   4486  2013-01-04      0              1
# 3   4997  2013-01-05      0              1
# 4   7176  2013-01-07      1              1
# 5   5580  2013-01-08      1              1
# 6   5471  2013-01-09      1              1
# 7   4892  2013-01-10      1              1
# 8   4881  2013-01-11      1              1
# 9   4952  2013-01-12      0              0

# %% [markdown]
# ## 1. LINEAR TREND MODELS

# %% [markdown]
# ### Date Conversion

# %% [markdown]
# Convert date to a data type that can be handled more effectively:

# %%
sales.info() #before, Date had Dtype object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales          781 non-null    int64
#  1   Date           781 non-null    object
#  2   Promo          781 non-null    int64
#  3   SchoolHoliday  781 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 24.5+ KB

# %%
sales['Date'] = pd.to_datetime(sales['Date'], infer_datetime_format=True)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales          781 non-null    int64
#  1   Date           781 non-null    datetime64[ns]
#  2   Promo          781 non-null    int64
#  3   SchoolHoliday  781 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 24.5 KB

# %%
year = sales['Date'].dt.year
print(year)
print("-------------------")
print(year.unique())
# Out:
# 0      2013
# 1      2013
# 2      2013
# 3      2013
# 4      2013
#        ...
# 776    2015
# 777    2015
# 778    2015
# 779    2015
# 780    2015
# Name: Date, Length: 781, dtype: int64
# -------------------
# [2013 2014 2015]

# %% [markdown]
# Similar to `year`, from the datetime variable we can also extract `quarter`, `month`, `day`, `day_name()`, etc.

# %% [markdown]
# ### Sequential Split
#
# We will split our trainig and test data according to chronological. For time series it's important not to incurr data leakage by splitting the dataset randomly.

# %%
sales_train = sales[sales['Date'].dt.year < 2015]
sales_test = sales[sales['Date'].dt.year >= 2015]

print(sales_train.shape, sales_test.shape)
# Out:
# (606, 4) (175, 4)

# %%
def plot_entire_series(x, y, **kwargs):
    
    plt.figure(figsize=(16, 4))
    plt.plot(x, y, linewidth=2, color='black')
    
    for key, value in kwargs.items():
        plt.plot(x, value, linewidth=2, color=key)
        
    plt.xlabel('Date', fontsize=16)
    plt.ylabel('Sales', fontsize=16)
    plt.show()
    
    return None

# %% [markdown]
# **[Sidenote]:** https://book.pythontips.com/en/latest/args_and_kwargs.html
#
# `**kwargs` and `*args` appearing in the function definition allows us to pass optional inputs that are not necessarily required. Moreover, in the case of out plotting function we use `**kwargs`, as it will allow us to pass key-worded arguments: this will be helpful to plot more than one curve in each of our figures.

# %%
# We pass the data to matplotlib as numpy arrays simply to avoid warnings
x = sales_train['Date'].to_numpy()
y = sales_train['Sales'].to_numpy()

plot_entire_series(x, y)

# %% [markdown]
# ### Linear Trend

# %%
time_period = list(range(len(sales_train)))

sales_train_lm = sales_train.copy()
sales_train_lm['TimePeriod'] = time_period
sales_train_lm.tail()
# Out:
#      Sales       Date  Promo  SchoolHoliday  TimePeriod
# 601   3659 2014-12-24      0              1         601
# 602   6057 2014-12-27      0              1         602
# 603   6463 2014-12-29      0              1         603
# 604   6466 2014-12-30      0              1         604
# 605   2605 2014-12-31      0              1         605

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula='Sales ~ TimePeriod', data=sales_train_lm).fit()

print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8374
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):              0.361
# Time:                        13:13:38   Log-Likelihood:                -5076.3
# No. Observations:                 606   AIC:                         1.016e+04
# Df Residuals:                     604   BIC:                         1.017e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4893.6771     85.450     57.270      0.000    4725.863    5061.492
# TimePeriod    -0.2238      0.245     -0.915      0.361      -0.704       0.256
# ==============================================================================
# Omnibus:                       92.720   Durbin-Watson:                   0.626
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.142
# Skew:                           0.956   Prob(JB):                     5.57e-34
# Kurtosis:                       4.551   Cond. No.                         698.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = sales_train['Date'].to_numpy()
y = sales_train['Sales'].to_numpy()
y_pred = lm.predict(sales_train_lm).to_numpy()

plot_entire_series(x, y, red=y_pred)

# %% [markdown]
# ## 2. RANDOM WALK MODELS

# %%
sales_train_rw = sales_train.copy()

sales_train_rw['SalesYesterday'] = sales_train['Sales'].shift(1)
sales_train_rw.head()
# Out:
#    Sales       Date  Promo  SchoolHoliday  SalesYesterday
# 0   5530 2013-01-02      0              1             NaN
# 1   4327 2013-01-03      0              1          5530.0
# 2   4486 2013-01-04      0              1          4327.0
# 3   4997 2013-01-05      0              1          4486.0
# 4   7176 2013-01-07      1              1          4997.0

# %%
x = sales_train_rw['Date'].to_numpy()
y = sales_train_rw['Sales'].to_numpy()
y_pred = sales_train_rw['SalesYesterday'].to_numpy()

plot_entire_series(x, y, red=y_pred)

# %% [markdown]
# #### Let us zoom in and take a closer look at the last 50 predictions

# %%
def plot_last_fifty(x, y, **kwargs):
    
    plt.figure(figsize=(16, 4))
    plt.scatter(x[-50:], y[-50:], linewidth=3, color='black')
    plt.plot(x[-50:], y[-50:], linewidth=3, color='black')
    
    for key, value in kwargs.items():
        plt.plot(x[-50:], value[-50:], linewidth=3, color=key)
        
    plt.xlabel('Date', fontsize=16)
    plt.ylabel('Sales', fontsize=16)
    plt.show()
    
    return None

# %%
plot_last_fifty(x, y, red=y_pred)

# %%
print((abs(sales_train_rw['Sales'] - 
           sales_train_rw['SalesYesterday']) >= 1000).value_counts())
# Out:
# False    516
# True      90
# dtype: int64

# %%
from sklearn.metrics import r2_score

# Here we slice the series using [1:] in order to discard the first entry which corresponds to a NaN.
print('Training R2:', round(r2_score(sales_train_rw['Sales'][1:], sales_train_rw['SalesYesterday'][1:]), 5))
# Out:
# Training R2: 0.3744

# %% [markdown]
# ## 3. AUTO-REGRESSIVE MODELS

# %% [markdown]
# ### Simple Auto-regressive Model

# %%
# when shall we use AR(1) model? (Go to hand-written notes)

sales_train_ar = sales_train_rw.copy()

#Yt = (1-w)*mu + w*Y(t-1)+epsilon

ar1 = smf.ols(formula='Sales ~ SalesYesterday', data=sales_train_ar).fit()
print(ar1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     536.5
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):           2.18e-85
# Time:                        13:13:39   Log-Likelihood:                -4876.1
# No. Observations:                 605   AIC:                             9756.
# Df Residuals:                     603   BIC:                             9765.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       1499.8007    146.896     10.210      0.000    1211.311    1788.290
# SalesYesterday     0.6885      0.030     23.163      0.000       0.630       0.747
# ==============================================================================
# Omnibus:                       81.325   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              724.116
# Skew:                          -0.178   Prob(JB):                    5.76e-158
# Kurtosis:                       8.348   Cond. No.                     2.33e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x = sales_train_ar['Date'].to_numpy()
y = sales_train_ar['Sales'].to_numpy()
y_pred = ar1.predict(sales_train_ar).to_numpy()

plot_entire_series(x, y, red=y_pred)
plot_last_fifty(x, y, red=y_pred)

# %%
print((abs(sales_train_ar['Sales'] - ar1.predict(sales_train_ar))
       >= 1000).value_counts())
# Out:
# False    523
# True      83
# dtype: int64

# %% [markdown]
# ### Higher-order Auto-regressive Model

# %%
sales_train_ar['SalesTwoDaysAgo'] = sales_train['Sales'].shift(2)

ar2 = smf.ols(formula='Sales ~ SalesYesterday + SalesTwoDaysAgo', data=sales_train_ar).fit()
print(ar2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     269.1
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):           3.41e-84
# Time:                        13:13:39   Log-Likelihood:                -4867.5
# No. Observations:                 604   AIC:                             9741.
# Df Residuals:                     601   BIC:                             9754.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1454.8297    159.104      9.144      0.000    1142.363    1767.296
# SalesYesterday      0.6699      0.041     16.188      0.000       0.589       0.751
# SalesTwoDaysAgo     0.0282      0.041      0.681      0.496      -0.053       0.110
# ==============================================================================
# Omnibus:                       82.448   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              730.080
# Skew:                          -0.204   Prob(JB):                    2.92e-159
# Kurtosis:                       8.371   Cond. No.                     3.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **No significant improvement -- better to keep the simpler AR1 model**

# %% [markdown]
# ### Incorporating Seasonality

# %%
sales_train_ar['Month'] = sales_train_ar['Date'].dt.month_name()
sales_train_ar['DayWeek'] = sales_train_ar['Date'].dt.day_name()
sales_train_ar.tail()
# Out:
#      Sales       Date  Promo  SchoolHoliday  SalesYesterday  SalesTwoDaysAgo  \
# 601   3659 2014-12-24      0              1          7959.0           9331.0
# 602   6057 2014-12-27      0              1          3659.0           7959.0
# 603   6463 2014-12-29      0              1          6057.0           3659.0
# 604   6466 2014-12-30      0              1          6463.0           6057.0
# 605   2605 2014-12-31      0              1          6466.0           6463.0
#
#         Month    DayWeek
# 601  December  Wednesday
# 602  December   Saturday
# 603  December     Monday
# 604  December    Tuesday
# 605  December  Wednesday

# %%
avg_sales_by_month = sales_train_ar.groupby('Month', sort=False).mean()['Sales']
avg_sales_by_month
# Out:
# /var/folders/ql/wwzgcgqn4gdd5ylht69yct1r0000gn/T/ipykernel_13140/1861747494.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sales_by_month = sales_train_ar.groupby('Month', sort=False).mean()['Sales']
# Month
# January      4754.711538
# February     4910.520833
# March        5130.117647
# April        4761.244898
# May          4915.416667
# June         4610.750000
# July         4641.407407
# August       4326.867925
# September    4220.882353
# October      4414.192308
# November     5067.607843
# December     6248.857143
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(9, 5))
avg_sales_by_month.plot(kind="bar")
plt.ylabel('Sales')
plt.xlabel('Month')
plt.show()

# %%
avg_sales_by_day = sales_train_ar.groupby('DayWeek', sort=False).mean()['Sales']

plt.figure(figsize=(8, 5))
avg_sales_by_day.plot(kind="bar")
plt.ylabel('Sales')
plt.xlabel('Month')
plt.show()
# Out:
# /var/folders/ql/wwzgcgqn4gdd5ylht69yct1r0000gn/T/ipykernel_13140/1171799166.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sales_by_day = sales_train_ar.groupby('DayWeek', sort=False).mean()['Sales']

# %%
ar3 = smf.ols(formula='Sales ~ SalesYesterday + DayWeek + Month', data=sales_train_ar).fit()
print(ar3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     42.48
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):           1.72e-90
# Time:                        13:13:39   Log-Likelihood:                -4826.0
# No. Observations:                 605   AIC:                             9688.
# Df Residuals:                     587   BIC:                             9767.
# Df Model:                          17
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             1989.3621    192.103     10.356      0.000    1612.069    2366.655
# DayWeek[T.Monday]      107.6731    102.499      1.050      0.294     -93.636     308.982
# DayWeek[T.Saturday]    -63.0128    100.955     -0.624      0.533    -261.289     135.263
# DayWeek[T.Thursday]   -383.2989    102.467     -3.741      0.000    -584.545    -182.052
# DayWeek[T.Tuesday]    -587.7652    103.480     -5.680      0.000    -791.000    -384.530
# DayWeek[T.Wednesday]  -410.3542    101.491     -4.043      0.000    -609.683    -211.025
# Month[T.August]       -199.1965    142.555     -1.397      0.163    -479.176      80.783
# Month[T.December]      425.5071    154.395      2.756      0.006     122.273     728.742
# Month[T.February]       43.5212    145.431      0.299      0.765    -242.107     329.149
# Month[T.January]         2.5806    143.236      0.018      0.986    -278.736     283.898
# Month[T.July]          -49.6116    141.251     -0.351      0.726    -327.030     227.807
# Month[T.June]          -92.3685    145.439     -0.635      0.526    -378.014     193.276
# Month[T.March]         152.9749    143.554      1.066      0.287    -128.968     434.917
# Month[T.May]            45.9504    145.515      0.316      0.752    -239.843     331.744
# Month[T.November]      154.4763    143.384      1.077      0.282    -127.132     436.084
# Month[T.October]      -133.0529    142.935     -0.931      0.352    -413.778     147.673
# Month[T.September]    -222.5370    144.396     -1.541      0.124    -506.133      61.059
# SalesYesterday           0.6316      0.033     18.922      0.000       0.566       0.697
# ==============================================================================
# Omnibus:                      149.613   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1085.504
# Skew:                          -0.887   Prob(JB):                    1.93e-236
# Kurtosis:                       9.318   Cond. No.                     6.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create separate variable for December, since it's the only month significantly different from April (the reference level)

sales_train_ar['MonthDecember'] = np.where(sales_train_ar['Month'] == 'December', 1, 0)

ar4 = smf.ols(formula='Sales ~ SalesYesterday + DayWeek + MonthDecember', data=sales_train_ar).fit()
print(ar4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.540
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     100.2
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):           1.93e-96
# Time:                        13:13:40   Log-Likelihood:                -4833.6
# No. Observations:                 605   AIC:                             9683.
# Df Residuals:                     597   BIC:                             9718.
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             1812.9408    158.107     11.467      0.000    1502.427    2123.455
# DayWeek[T.Monday]       89.0088    102.694      0.867      0.386    -112.677     290.694
# DayWeek[T.Saturday]    -71.5948    101.309     -0.707      0.480    -270.561     127.371
# DayWeek[T.Thursday]   -390.9919    102.752     -3.805      0.000    -592.790    -189.194
# DayWeek[T.Tuesday]    -616.0439    103.512     -5.951      0.000    -819.336    -412.752
# DayWeek[T.Wednesday]  -421.9859    101.755     -4.147      0.000    -621.826    -222.145
# SalesYesterday           0.6658      0.032     20.640      0.000       0.602       0.729
# MonthDecember          396.0644    120.363      3.291      0.001     159.679     632.450
# ==============================================================================
# Omnibus:                      143.645   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1080.127
# Skew:                          -0.831   Prob(JB):                    2.84e-235
# Kurtosis:                       9.332   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Add Promo and SchoolHoliday as well

ar5 = smf.ols(formula='Sales ~ SalesYesterday + DayWeek + MonthDecember + Promo + SchoolHoliday',
              data=sales_train_ar).fit()
print(ar5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.632
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     113.6
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):          4.82e-123
# Time:                        13:13:40   Log-Likelihood:                -4766.1
# No. Observations:                 605   AIC:                             9552.
# Df Residuals:                     595   BIC:                             9596.
# Df Model:                           9
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             2403.9892    150.086     16.017      0.000    2109.226    2698.753
# DayWeek[T.Monday]      167.7970     92.229      1.819      0.069     -13.337     348.931
# DayWeek[T.Saturday]    441.0537    100.413      4.392      0.000     243.847     638.260
# DayWeek[T.Thursday]   -377.5738     92.062     -4.101      0.000    -558.380    -196.767
# DayWeek[T.Tuesday]    -450.0369     93.728     -4.801      0.000    -634.116    -265.958
# DayWeek[T.Wednesday]  -369.8847     91.261     -4.053      0.000    -549.117    -190.652
# SalesYesterday           0.4349      0.035     12.571      0.000       0.367       0.503
# MonthDecember          827.9466    113.500      7.295      0.000     605.038    1050.856
# Promo                  835.2593     69.055     12.096      0.000     699.637     970.881
# SchoolHoliday          -93.1816     62.521     -1.490      0.137    -215.969      29.606
# ==============================================================================
# Omnibus:                       73.365   Durbin-Watson:                   1.827
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              538.686
# Skew:                          -0.193   Prob(JB):                    1.06e-117
# Kurtosis:                       7.607   Cond. No.                     3.27e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Remove SchoolHoliday

ar6 = smf.ols(formula='Sales ~ SalesYesterday + DayWeek + MonthDecember + Promo', data=sales_train_ar).fit()
print(ar6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     127.3
# Date:                Tue, 26 Dec 2023   Prob (F-statistic):          1.24e-123
# Time:                        13:13:40   Log-Likelihood:                -4767.2
# No. Observations:                 605   AIC:                             9552.
# Df Residuals:                     596   BIC:                             9592.
# Df Model:                           8
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             2379.3166    149.323     15.934      0.000    2086.053    2672.581
# DayWeek[T.Monday]      166.6320     92.320      1.805      0.072     -14.680     347.944
# DayWeek[T.Saturday]    446.5517    100.448      4.446      0.000     249.277     643.826
# DayWeek[T.Thursday]   -378.6042     92.154     -4.108      0.000    -559.590    -197.618
# DayWeek[T.Tuesday]    -452.3391     93.812     -4.822      0.000    -636.581    -268.097
# DayWeek[T.Wednesday]  -370.7688     91.352     -4.059      0.000    -550.180    -191.357
# SalesYesterday           0.4356      0.035     12.579      0.000       0.368       0.504
# MonthDecember          823.1222    113.570      7.248      0.000     600.076    1046.168
# Promo                  836.0757     69.124     12.095      0.000     700.320     971.832
# ==============================================================================
# Omnibus:                       79.214   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              585.690
# Skew:                          -0.273   Prob(JB):                    6.59e-128
# Kurtosis:                       7.789   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Use ar6 as the final Auto-regressive model for prediction
y_pred = ar6.predict(sales_train_ar).to_numpy()

plot_entire_series(x, y, red=y_pred)
plot_last_fifty(x, y, red=y_pred)

# %% [markdown]
# ## 4. RANDOM FOREST MODELS

# %%
sales_train_rf = sales_train_ar.drop(['Date', 'MonthDecember'], axis=1).copy()
sales_train_rf['Month'] = sales_train['Date'].dt.month_name()
sales_train_rf['DayWeek'] = sales_train['Date'].dt.day_name()
sales_train_rf.head()
# Out:
#    Sales  Promo  SchoolHoliday  SalesYesterday  SalesTwoDaysAgo    Month  \
# 0   5530      0              1             NaN              NaN  January
# 1   4327      0              1          5530.0              NaN  January
# 2   4486      0              1          4327.0           5530.0  January
# 3   4997      0              1          4486.0           4327.0  January
# 4   7176      1              1          4997.0           4486.0  January
#
#      DayWeek
# 0  Wednesday
# 1   Thursday
# 2     Friday
# 3   Saturday
# 4     Monday

# %% [markdown]
# ### Categorical Encoding

# %%
sales_train_rf = pd.get_dummies(sales_train_rf, dtype=int)
sales_train_rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 606 entries, 0 to 605
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales              606 non-null    int64
#  1   Promo              606 non-null    int64
#  2   SchoolHoliday      606 non-null    int64
#  3   SalesYesterday     605 non-null    float64
#  4   SalesTwoDaysAgo    604 non-null    float64
#  5   Month_April        606 non-null    int64
#  6   Month_August       606 non-null    int64
#  7   Month_December     606 non-null    int64
#  8   Month_February     606 non-null    int64
#  9   Month_January      606 non-null    int64
#  10  Month_July         606 non-null    int64
#  11  Month_June         606 non-null    int64
#  12  Month_March        606 non-null    int64
#  13  Month_May          606 non-null    int64
#  14  Month_November     606 non-null    int64
#  15  Month_October      606 non-null    int64
#  16  Month_September    606 non-null    int64
#  17  DayWeek_Friday     606 non-null    int64
#  18  DayWeek_Monday     606 non-null    int64
#  19  DayWeek_Saturday   606 non-null    int64
#  20  DayWeek_Thursday   606 non-null    int64
#  21  DayWeek_Tuesday    606 non-null    int64
#  22  DayWeek_Wednesday  606 non-null    int64
# dtypes: float64(2), int64(21)
# memory usage: 113.6 KB

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# Again we slice [2:] to discard the entries with NaN.
y_train_rf = sales_train_rf['Sales'].iloc[2:]
X_train_rf = sales_train_rf.drop(['Sales'], axis=1).iloc[2:]

rf = RandomForestRegressor(max_features=5, min_samples_leaf=5, n_estimators = 500, random_state=88)
rf.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestRegressor(max_features=5, min_samples_leaf=5, n_estimators=500,
#                       random_state=88)

# %%
x = sales_train_ar['Date'].iloc[2:].to_numpy()
y = y_train_rf.to_numpy()
y_pred_rf = rf.predict(X_train_rf)
y_pred_ar = ar6.predict(sales_train_ar).to_numpy()

plot_entire_series(x, y, limegreen=y_pred_rf)
plot_last_fifty(x, y, limegreen=y_pred_rf)
plot_last_fifty(x, y, limegreen=y_pred_rf, red=y_pred_ar)

# %% [markdown]
# ### Evaluation on Test Set
#
# Create the test set with the extra columns. Note that we could have avoided the duplication effort in building
# sales_train_rf and sales_test_rf by first adding all our variables to "sales" (our original data frame)
# and then splitting it.

# %%
def OSR2(model, X_test, y_test, y_train):
    
    y_pred = model.predict(X_test)
    SSE = np.sum((y_test - y_pred)**2)
    SST = np.sum((y_test - np.mean(y_train))**2)
                 
    return (1 - SSE/SST)

# %% [markdown]
# ### Random Forest on Test Set

# %%
sales_test_rf = sales_test.copy()
sales_test_rf['SalesYesterday'] = sales_test_rf['Sales'].shift(1)
sales_test_rf['SalesTwoDaysAgo'] = sales_test_rf['Sales'].shift(2)
sales_test_rf['Month'] = sales_test_rf['Date'].dt.month_name()
sales_test_rf['DayWeek'] = sales_test_rf['Date'].dt.day_name()
sales_test_rf = sales_test_rf.drop(['Date'], axis=1)

# Alignment of categorical encoding between train and test sets
sales_test_rf = pd.get_dummies(sales_test_rf, dtype=int)
sales_train_rf, sales_test_rf = sales_train_rf.align(sales_test_rf, join='left', axis=1)
sales_test_rf.fillna(0, inplace=True)

# %%
y_test_rf = sales_test_rf['Sales'].iloc[2:]
X_test_rf = sales_test_rf.drop(['Sales'], axis=1).iloc[2:]
print('Random Forest Model OSR2:', round(OSR2(rf, X_test_rf, y_test_rf, y_train_rf), 5))
# Out:
# Random Forest Model OSR2: 0.68426

# %% [markdown]
# ### Auto-regressive Model on Test Set

# %%
sales_test_ar = sales_test.copy()
sales_test_ar['SalesYesterday'] = sales_test_ar['Sales'].shift(1)
sales_test_ar['SalesTwoDaysAgo'] = sales_test_ar['Sales'].shift(2)
sales_test_ar['Month'] = sales_test_ar['Date'].dt.month_name()
sales_test_ar['DayWeek'] = sales_test_ar['Date'].dt.day_name()
sales_test_ar['MonthDecember'] = np.where(sales_test_ar['Month'] == 'December', 1, 0)
sales_test_ar = sales_test_ar.drop(['Date', 'SchoolHoliday', 'SalesTwoDaysAgo', 'Month'], axis=1)

# %%
y_test_ar = sales_test_ar['Sales'][1:]
y_train_ar = sales_train_ar['Sales'][1:]
print('Auto-regressive Model OSR2:', round(OSR2(ar6, sales_test_ar, y_test_ar, y_train_ar), 5))
# Out:
# Auto-regressive Model OSR2: 0.63861

# %% [markdown]
# ### Final Plot

# %%
# note that the green line is for the random forest regression model and the red line is for the auto-regressive model.

# %%
x = sales_test['Date'].iloc[2:].to_numpy()
y = y_test_rf.to_numpy()

y_pred_rf = rf.predict(X_test_rf)
y_pred_ar = ar6.predict(sales_test_ar)[1:]

plot_last_fifty(x, y, limegreen=y_pred_rf, red=y_pred_ar.to_numpy())
